# %%
#PyTorch imports
import torch  
import torchvision
import torchxrayvision as xrv

#TensorFlow
import tensorflow as tf

#Standarts
import numpy as np

# %%
resnet = tf.keras.applications.ResNet50(include_top=False, input_shape=(224,224,3), classes= 2)

# %%
transform = torchvision.transforms.Compose([xrv.datasets.XRayCenterCrop(),xrv.datasets.XRayResizer(224)])
idk = xrv.datasets.COVID19_Dataset(imgpath='D:\Licon\Xray\covid-chestxray-dataset\images',csvpath='D:\Licon\Xray\covid-chestxray-dataset\metadata.csv',transform=transform)

# %%
len_dataset=len(idk)
n_train=int(0.9*len_dataset)
n_test=int(0.1*len_dataset)+1
print(len_dataset,n_train,n_test)
# Out:
# 408 367 41

# %%
train_dataset,test_dataset=torch.utils.data.random_split(idk, [n_train,n_test])
dataset={'train':train_dataset,'test':test_dataset}
dataloaders = {x : torch.utils.data.DataLoader(dataset[x], batch_size=4,shuffle=True, num_workers=4) for x in ['train','test'] }

# %%
zeros = np.zeros((224,224))

# %%
resnet.trainable = False

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
for i, data in enumerate(dataloaders['train'], 0):
    data['img']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-d29c344dba92> in <module>
#       1 for i, data in enumerate(dataloaders['train'], 0):
# ----> 2     data['img'].shuffle(1).batch(1)
#
# AttributeError: 'Tensor' object has no attribute 'shuffle'

# %%
for epoch in range(20000):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(dataloaders['train'], 0):
        inputs=data['img'].cuda()
        labels=data['lab'].long().cuda()
        labels=labels[:,2]
       
        # get the inputs; data is a list of [inputs, labels]
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    test_loss=0.0

    for i, data in enumerate(dataloaders['test'], 0):
        inputs=data['PA'].cuda()
        labels=data['lab'].long().cuda()
        labels=labels[:,2]

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # print statistics
        test_loss += loss.item()

    print('Train',running_loss,'Test',test_loss)
print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a3d2793e24b5> in <module>
#       9         # get the inputs; data is a list of [inputs, labels]
#      10         # zero the parameter gradients
# ---> 11         optimizer.zero_grad()
#      12
#      13         # forward + backward + optimize
#
# NameError: name 'optimizer' is not defined
